# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"></ul></div>

# %% [markdown]
# 🔹 **Задание 1. Первичный анализ данных**
#
# 1. Загрузите файл в датафрейм и выведите первые 5 строк (Подсказка: найти в документации pandas, как читать csv файл, выставить разделителем запятую).
# 2. Первый столбец - индекс, который перезаписался как отдельный столбец: удалите его
# 3. Определите и выведите:
#
# * количество строк и столбцов
#
# * типы данных
#
# * общую информацию по таблице и краткую статистику по числовым столбцам
#
# * минимальное и максимальное значение по мировым сборам
#
# * уникальные жанры
#
# * количество фильмов по каждому рейтингу

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import re

df = pd.read_csv('movies.csv', sep=',')
df = df.drop(["Unnamed: 0"], axis=1).reset_index(drop=True)

# %%
df.shape
# Out:
# (918, 10)

# %%
df.dtypes
# Out:
# Title                         object
# Movie Info                    object
# Distributor                   object
# Release Date                  object
# Domestic Sales (in $)          int64
# International Sales (in $)     int64
# World Sales (in $)             int64
# Genre                         object
# Movie Runtime                 object
# License                       object
# dtype: object

# %%
df["World Sales (in $)"].min()
# Out:
# np.int64(81600000)

# %%
df["World Sales (in $)"].max()
# Out:
# np.int64(2847246203)

# %%
df.describe()
# Out:
#        Domestic Sales (in $)  International Sales (in $)  World Sales (in $)
# count           9.180000e+02                9.180000e+02        9.180000e+02
# mean            1.677469e+08                2.301434e+08        3.968668e+08
# std             1.040360e+08                2.176011e+08        3.082629e+08
# min             8.036084e+07                2.600000e+02        8.160000e+07
# 25%             1.016071e+08                8.845620e+07        2.005564e+08
# 50%             1.321351e+08                1.638819e+08        3.019416e+08
# 75%             1.913905e+08                2.885577e+08        4.750718e+08
# max             9.366622e+08                2.086739e+09        2.847246e+09

# %%
df["Distributor"].unique()
# Out:
# array(['Walt Disney Studios Motion Pictures', 'Twentieth Century Fox',
#        'Sony Pictures Entertainment (SPE)', 'Paramount Pictures',
#        'Universal Pictures', 'Warner Bros.', 'DreamWorks Distribution',
#        'Lionsgate', 'DreamWorks', 'New Line Cinema', 'Newmarket Films',
#        'Summit Entertainment', 'Columbia Pictures', 'IFC Films',
#        'TriStar Pictures', 'Orion Pictures', 'Metro-Goldwyn-Mayer (MGM)',
#        'Miramax', 'The Weinstein Company', 'Fox Searchlight Pictures',
#        'Revolution Studios', 'Artisan Entertainment',
#        'Sony Pictures Classics', 'United Artists', 'Screen Gems',
#        'USA Films', '20th Century Studios', 'STX Entertainment',
#        'Dimension Films', 'United Artists Releasing', 'FilmDistrict',
#        'Focus Features', 'Relativity Media', 'Roadside Attractions'],
#       dtype=object)

# %%
df["License"].value_counts()
# Out:
# License
# PG-13    363
# R        194
# PG       173
# G         14
# Name: count, dtype: int64

# %%
df.head()
# Out:
#                                                Title  \
# 0  Star Wars: Episode VII - The Force Awakens (2015)
# 1                           Avengers: Endgame (2019)
# 2                                      Avatar (2009)
# 3                               Black Panther (2018)
# 4                      Avengers: Infinity War (2018)
#
#                                           Movie Info  \
# 0  As a new threat to the galaxy rises, Rey, a de...
# 1  After the devastating events of Avengers: Infi...
# 2  A paraplegic Marine dispatched to the moon Pan...
# 3  T'Challa, heir to the hidden but advanced king...
# 4  The Avengers and their allies must be willing ...
#
#                            Distributor       Release Date  \
# 0  Walt Disney Studios Motion Pictures  December 16, 2015
# 1  Walt Disney Studios Motion Pictures     April 24, 2019
# 2                Twentieth Century Fox  December 16, 2009
# 3  Walt Disney Studios Motion Pictures                NaN
# 4  Walt Disney Studios Motion Pictures                NaN
#
#    Domestic Sales (in $)  International Sales (in $)  World Sales (in $)  \
# 0              936662225                  1132859475          2069521700
# 1              858373000                  1939128328          2797501328
# 2              760507625                  2086738578          2847246203
# 3              700426566                   647171407          1347597973
# 4              678815482                  1369544272          2048359754
#
#                                           Genre Movie Runtime License
# 0             ['Action', 'Adventure', 'Sci-Fi']   2 hr 18 min   PG-13
# 1    ['Action', 'Adventure', 'Drama', 'Sci-Fi']    3 hr 1 min   PG-13
# 2  ['Action', 'Adventure', 'Fantasy', 'Sci-Fi']   2 hr 42 min   PG-13
# 3             ['Action', 'Adventure', 'Sci-Fi']   2 hr 14 min     NaN
# 4             ['Action', 'Adventure', 'Sci-Fi']   2 hr 29 min     NaN

# %% [markdown]
# 🔹 **Задание 2. Обработка пропусков и создание новых признаков**
#
# 1. Проверьте, в каких столбцах есть пропуски.
# 2. Замените пропуски в столбце с рейтингом на самое частотное значение (Подсказка: заменить на mode()[0]).
# 3. Удалите все строки с пропусками в дате релиза.
# 3. Добавьте новый столбец: доля домашних сборов относительно мировых.

# %%
df.isna().sum()
# Out:
# Title                           0
# Movie Info                      0
# Distributor                     0
# Release Date                  118
# Domestic Sales (in $)           0
# International Sales (in $)      0
# World Sales (in $)              0
# Genre                           0
# Movie Runtime                   0
# License                       174
# dtype: int64

# %%
df["License"] = df["License"].fillna(df["License"].mode()[0])

# %%
df = df.dropna().reset_index(drop=True)

# %%
df["Share of Domestic Sales in comparison with World Sales (in $)"] = (df["Domestic Sales (in $)"] * 100)/ df["World Sales (in $)"]

# %%
df.head()
# Out:
#                                                Title  \
# 0  Star Wars: Episode VII - The Force Awakens (2015)
# 1                           Avengers: Endgame (2019)
# 2                                      Avatar (2009)
# 3                                     Titanic (1997)
# 4                              Jurassic World (2015)
#
#                                           Movie Info  \
# 0  As a new threat to the galaxy rises, Rey, a de...
# 1  After the devastating events of Avengers: Infi...
# 2  A paraplegic Marine dispatched to the moon Pan...
# 3  A seventeen-year-old aristocrat falls in love ...
# 4  A new theme park, built on the original site o...
#
#                            Distributor       Release Date  \
# 0  Walt Disney Studios Motion Pictures  December 16, 2015
# 1  Walt Disney Studios Motion Pictures     April 24, 2019
# 2                Twentieth Century Fox  December 16, 2009
# 3                   Paramount Pictures  December 19, 1997
# 4                   Universal Pictures      June 10, 2015
#
#    Domestic Sales (in $)  International Sales (in $)  World Sales (in $)  \
# 0              936662225                  1132859475          2069521700
# 1              858373000                  1939128328          2797501328
# 2              760507625                  2086738578          2847246203
# 3              659363944                  1542283320          2201647264
# 4              652385625                  1018130819          1670516444
#
#                                           Genre Movie Runtime License  \
# 0             ['Action', 'Adventure', 'Sci-Fi']   2 hr 18 min   PG-13
# 1    ['Action', 'Adventure', 'Drama', 'Sci-Fi']    3 hr 1 min   PG-13
# 2  ['Action', 'Adventure', 'Fantasy', 'Sci-Fi']   2 hr 42 min   PG-13
# 3                          ['Drama', 'Romance']   3 hr 14 min   PG-13
# 4             ['Action', 'Adventure', 'Sci-Fi']    2 hr 4 min   PG-13
#
#    Share of Domestic Sales in comparison with World Sales (in $)
# 0                                          45.259841
# 1                                          30.683560
# 2                                          26.710287
# 3                                          29.948664
# 4                                          39.052930

# %% [markdown]
# 🔹 **Задание 3. Работа с датами**
#
# 1. Преобразуйте столбец Release Date в тип datetime (Подсказка: найти в документации pandas, как вызывать функцию to_datetime).
# 2. Добавьте новый столбец Year, извлекая из даты только год (Подсказка: найти в документации pandas, как вызывать функцию dt.year).

# %%
df["Release Date"] = pd.to_datetime(df["Release Date"])

# %%
df["Year"] = df["Release Date"].dt.year

# %%
df.head()
# Out:
#                                                Title  \
# 0  Star Wars: Episode VII - The Force Awakens (2015)
# 1                           Avengers: Endgame (2019)
# 2                                      Avatar (2009)
# 3                                     Titanic (1997)
# 4                              Jurassic World (2015)
#
#                                           Movie Info  \
# 0  As a new threat to the galaxy rises, Rey, a de...
# 1  After the devastating events of Avengers: Infi...
# 2  A paraplegic Marine dispatched to the moon Pan...
# 3  A seventeen-year-old aristocrat falls in love ...
# 4  A new theme park, built on the original site o...
#
#                            Distributor Release Date  Domestic Sales (in $)  \
# 0  Walt Disney Studios Motion Pictures   2015-12-16              936662225
# 1  Walt Disney Studios Motion Pictures   2019-04-24              858373000
# 2                Twentieth Century Fox   2009-12-16              760507625
# 3                   Paramount Pictures   1997-12-19              659363944
# 4                   Universal Pictures   2015-06-10              652385625
#
#    International Sales (in $)  World Sales (in $)  \
# 0                  1132859475          2069521700
# 1                  1939128328          2797501328
# 2                  2086738578          2847246203
# 3                  1542283320          2201647264
# 4                  1018130819          1670516444
#
#                                           Genre Movie Runtime License  \
# 0             ['Action', 'Adventure', 'Sci-Fi']   2 hr 18 min   PG-13
# 1    ['Action', 'Adventure', 'Drama', 'Sci-Fi']    3 hr 1 min   PG-13
# 2  ['Action', 'Adventure', 'Fantasy', 'Sci-Fi']   2 hr 42 min   PG-13
# 3                          ['Drama', 'Romance']   3 hr 14 min   PG-13
# 4             ['Action', 'Adventure', 'Sci-Fi']    2 hr 4 min   PG-13
#
#    Share of Domestic Sales in comparison with World Sales (in $)  Year
# 0                                          45.259841              2015
# 1                                          30.683560              2019
# 2                                          26.710287              2009
# 3                                          29.948664              1997
# 4                                          39.052930              2015

# %% [markdown]
# 🔹 **Задание 4. Фильтрация данных и срезы**
#
# 1. Найдите и выведите фильмы с 10 по 20 строку:
#
# * с домашними сборами больше 70 миллионов (только столбцы с названиями фильмов и домашними сборами)
#
# * со мстителями (в названии есть "Avengers") (только столбцы с названиями фильмов и описанием)
#
# * 20-ого века и студии Paramount Pictures (только столбцы с названиями фильмов, годом и студией)
#
# 2. Отсортируйте и пересохраните таблицу в порядке убывания мировых сборов.

# %%
df.loc[(df["Domestic Sales (in $)"]>70000000), ["Title", "Domestic Sales (in $)"]].head()
# Out:
#                                                Title  Domestic Sales (in $)
# 0  Star Wars: Episode VII - The Force Awakens (2015)              936662225
# 1                           Avengers: Endgame (2019)              858373000
# 2                                      Avatar (2009)              760507625
# 3                                     Titanic (1997)              659363944
# 4                              Jurassic World (2015)              652385625

# %%
df.loc[(df["Title"].str.contains("Avengers")), ["Title", "Movie Info"]]
# Out:
#                              Title  \
# 1         Avengers: Endgame (2019)
# 5              The Avengers (2012)
# 15  Avengers: Age of Ultron (2015)
#
#                                            Movie Info
# 1   After the devastating events of Avengers: Infi...
# 5   Earth's mightiest heroes must come together an...
# 15  When Tony Stark and Bruce Banner try to jump-s...

# %%
df.loc[(df["Year"]<2000) & (df["Distributor"].str.contains("Paramount Pictures")), ["Title", "Distributor", "Year"]].head()
# Out:
#                                                  Title         Distributor  \
# 3                                       Titanic (1997)  Paramount Pictures
# 59                                 Forrest Gump (1994)  Paramount Pictures
# 118  Indiana Jones and the Raiders of the Lost Ark ...  Paramount Pictures
# 155                                       Ghost (1990)  Paramount Pictures
# 198          Indiana Jones and the Last Crusade (1989)  Paramount Pictures
#
#      Year
# 3    1997
# 59   1994
# 118  1981
# 155  1990
# 198  1989

# %%
df.sort_values(["World Sales (in $)"], ascending=False, inplace=True)

# %%
df.reset_index(drop=True).head()
# Out:
#                                                Title  \
# 0                                      Avatar (2009)
# 1                           Avengers: Endgame (2019)
# 2                                     Titanic (1997)
# 3  Star Wars: Episode VII - The Force Awakens (2015)
# 4                              Jurassic World (2015)
#
#                                           Movie Info  \
# 0  A paraplegic Marine dispatched to the moon Pan...
# 1  After the devastating events of Avengers: Infi...
# 2  A seventeen-year-old aristocrat falls in love ...
# 3  As a new threat to the galaxy rises, Rey, a de...
# 4  A new theme park, built on the original site o...
#
#                            Distributor Release Date  Domestic Sales (in $)  \
# 0                Twentieth Century Fox   2009-12-16              760507625
# 1  Walt Disney Studios Motion Pictures   2019-04-24              858373000
# 2                   Paramount Pictures   1997-12-19              659363944
# 3  Walt Disney Studios Motion Pictures   2015-12-16              936662225
# 4                   Universal Pictures   2015-06-10              652385625
#
#    International Sales (in $)  World Sales (in $)  \
# 0                  2086738578          2847246203
# 1                  1939128328          2797501328
# 2                  1542283320          2201647264
# 3                  1132859475          2069521700
# 4                  1018130819          1670516444
#
#                                           Genre Movie Runtime License  \
# 0  ['Action', 'Adventure', 'Fantasy', 'Sci-Fi']   2 hr 42 min   PG-13
# 1    ['Action', 'Adventure', 'Drama', 'Sci-Fi']    3 hr 1 min   PG-13
# 2                          ['Drama', 'Romance']   3 hr 14 min   PG-13
# 3             ['Action', 'Adventure', 'Sci-Fi']   2 hr 18 min   PG-13
# 4             ['Action', 'Adventure', 'Sci-Fi']    2 hr 4 min   PG-13
#
#    Share of Domestic Sales in comparison with World Sales (in $)  Year
# 0                                          26.710287              2009
# 1                                          30.683560              2019
# 2                                          29.948664              1997
# 3                                          45.259841              2015
# 4                                          39.052930              2015

# %% [markdown]
# 🔹 **Задание 5. Группировка, агрегация и визуализация**
#
# 1. Создайте таблицу с группировкой: сколько фильмов вышло в каждом году.
# 2. Постройте график по этим данным с:
# * подписями осей
# * названием графика
# * сеткой
#
# 3. Создайте таблицу с двойной группировкой: сколько суммарно общемировых сборов собрала каждая студия, сколько фильмов каждая студия сняла.
# 4. Постройте сабплоты: две столбчатые диаграммы друг под другом по этим данным с:
# * размером фигуры 12 * 12
# * подписями осей
# * названием графика
# * цветовой палитрой
# * повернутыми на 90 градусов лейблами на оси X
# * перед выводом графика добавьте plt.tight_layot(), чтобы графики не накладывались друг на друга

# %%
movies_per_year = (
    df.groupby("Year")["Title"].count().reset_index()
)

# %%
movies_per_year.head()
# Out:
#    Year  Title
# 0  1972      1
# 1  1975      1
# 2  1977      1
# 3  1978      2
# 4  1979      2

# %%
plt.figure()
plt.plot(movies_per_year["Year"], movies_per_year["Title"])
plt.title("Количество фильмов выпущенных в год")
plt.xlabel("Кол-во")
plt.ylabel("Год")

plt.grid(True)
plt.show()

# %%
amount_of_every = (
    df.groupby("Distributor")
    .agg(am_world_sales = ("World Sales (in $)", "sum"), am_movies = ("Title", "count")).sort_values(["am_world_sales"], ascending=False))

# %%
amount_of_every
# Out:
#                                      am_world_sales  am_movies
# Distributor
# Walt Disney Studios Motion Pictures     66064206388        116
# Warner Bros.                            51278674921        131
# Twentieth Century Fox                   45810462591        107
# Universal Pictures                      43737868860        114
# Sony Pictures Entertainment (SPE)       34510533028         97
# Paramount Pictures                      29617345087         86
# DreamWorks                               9917749677         19
# Lionsgate                                6930240507         16
# New Line Cinema                          6743074481         19
# DreamWorks Distribution                  5272576107         16
# Summit Entertainment                     2729159486          5
# TriStar Pictures                         2483548026          9
# Metro-Goldwyn-Mayer (MGM)                1981226629          7
# Miramax                                  1832657727          8
# The Weinstein Company                    1588632685          5
# Revolution Studios                       1442436078          8
# Columbia Pictures                        1288912626          6
# Dimension Films                          1223005113          7
# Fox Searchlight Pictures                  940181269          3
# Orion Pictures                            835497402          3
# Newmarket Films                           612054506          1
# STX Entertainment                         467355852          3
# Screen Gems                               449946079          3
# Focus Features                            415922809          2
# IFC Films                                 368744044          1
# FilmDistrict                              332189519          2
# Artisan Entertainment                     248639099          1
# Relativity Media                          226904017          1
# Sony Pictures Classics                    213525736          1
# United Artists Releasing                  203783845          1
# United Artists                            201545517          1
# Roadside Attractions                       86086881          1

# %%
plt.figure(figsize=(12,12))

plt.subplot(1,2,1)

sns.barplot(data=amount_of_every, x="Distributor", y="am_world_sales", hue="Distributor", palette="Blues_d")
plt.title("Суммарные сборы по миру")
plt.ylabel("Студия")
plt.xlabel("Сборы")
plt.xticks(rotation=90)
plt.figure(figsize=(12,12))
plt.subplot(1,2,2)

sns.barplot(data=amount_of_every, x="am_movies", y="Distributor",  hue="Distributor", palette="Greens_d", legend=False)
plt.title("Выпушенные фильмы")
plt.ylabel("Студия")
plt.xlabel("Кол-во фильмов")

plt.xticks(rotation=90)
plt.tight_layout()

# %% [markdown]
# 🔹 **Задание 6. Кастомные функции и применение apply()**
#
# 1. Напишите функцию movie_runtime_minutes, которая переведет длительность фильмов из текстового формата в минуты:
# * как один из вариантов, можно найти оба числа, то есть часы и минуты, с помощью re.findall("[0-9]{1, }", x), не забыв импортировать библиотеку re
# * сохранить это как список, затем умножить первое число (час) из списка на 60, прибавить второе число (минуты): не забыть учесть, что не во всех фильмах указаны минуты - значит, нужно прописать отдельные условия, если есть и часы, и минуты, или есть только часы
# * не забыть, что элементы в списке - строковые, нужно перевести их в числа: условно будет int(numbers[0])*60 + ...
# 2. Примените функцию к таблице, создав новый столбец Movie Runtime Minutes.

# %%
def movie_runtime_minutes(x):
    time_info = re.findall("[0-9]{1,}", ["Movie Runtime"])
    if len(time_info) == 1:
        minutes = int(time_info[0])*60
    else:
        minutes = int(time_info[0])*60+int(time_info[1])
        
    print(minutes)
    
movie_runtime_minutes()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[86], line 12
#       6         minutes = int(time_info[0])*60+int(time_info[1])
#       8     print(minutes)
# ---> 12 movie_runtime_minutes()
#
# Cell In[86], line 2, in movie_runtime_minutes()
#       1 def movie_runtime_minutes():
# ----> 2     time_info = re.findall("[0-9]{1,}", ["Movie Runtime"])
#       3     if len(time_info) == 1:
#       4         minutes = int(time_info[0])*60
#
# File ~\anaconda3\Lib\re\__init__.py:278, in findall(pattern, string, flags)
#     270 def findall(pattern, string, flags=0):
#     271     """Return a list of all non-overlapping matches in the string.
#     272
#     273     If one or more capturing groups are present in the pattern, return
#    (...)
#     276
#     277     Empty matches are included in the result."""
# --> 278     return _compile(pattern, flags).findall(string)
#
# TypeError: expected string or bytes-like object, got 'list'

# %% [markdown]
# 🔹 **Задание 7. Визуализация корреляций**
#
# 1. Выведите корреляционную матрицу по числовым признакам в таблице.
# 2. Постройте тепловую карту по этим данным с названием графика.
# 3. Напишите в отдельной ячейке markdown, есть ли взаимосвязь между продолжительностью фильма и его сборами?
# 4. Постройте диаграмму рассеяния между признаками, у которых наибольшая корреляция (Подсказка: в документации найдите matplotlib scatter, какие обязательные параметры туда нужно передать).
# 5. Сохраните итоговую таблицу в excel.

# %%
df.corr(numeric_only=True)
# Out:
#                                                     Domestic Sales (in $)  \
# Domestic Sales (in $)                                            1.000000
# International Sales (in $)                                       0.792538
# World Sales (in $)                                               0.901854
# Share of Domestic Sales in comparison with Worl...              -0.202097
# Year                                                             0.094280
#
#                                                     International Sales (in $)  \
# Domestic Sales (in $)                                                 0.792538
# International Sales (in $)                                            1.000000
# World Sales (in $)                                                    0.977177
# Share of Domestic Sales in comparison with Worl...                   -0.603485
# Year                                                                  0.247533
#
#                                                     World Sales (in $)  \
# Domestic Sales (in $)                                         0.901854
# International Sales (in $)                                    0.977177
# World Sales (in $)                                            1.000000
# Share of Domestic Sales in comparison with Worl...           -0.504463
# Year                                                          0.210808
#
#                                                     Share of Domestic Sales in comparison with World Sales (in $)  \
# Domestic Sales (in $)                                                                       -0.202097
# International Sales (in $)                                                                  -0.603485
# World Sales (in $)                                                                          -0.504463
# Share of Domestic Sales in comparison with Worl...                                           1.000000
# Year                                                                                        -0.281643
#
#                                                         Year
# Domestic Sales (in $)                               0.094280
# International Sales (in $)                          0.247533
# World Sales (in $)                                  0.210808
# Share of Domestic Sales in comparison with Worl... -0.281643
# Year                                                1.000000

# %%
plt.figure(figsize=(12, 5))
plt.subplot(1,2,1)
df.plot.scatter(x= 'World Sales (in $)', y='International Sales (in $)', ax=plt.gca())

plt.subplot(1,2,2)
df.plot.scatter(x='World Sales (in $)', y='Domestic Sales (in $)', ax=plt.gca())

plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(8,6))
sns.heatmap(
    df.corr(numeric_only=True),
    cmap="coolwarm",
    linewidths=0.5,
)

plt.title("Тепловая карта корреляций числовых признаков", fontsize=12)

plt.show()

# %%
df.to_excel("Данные.xlsx", index=False, engine='openpyxl')
